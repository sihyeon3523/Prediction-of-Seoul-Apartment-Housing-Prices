# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# %matplotlib inline

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
data = pd.read_excel("C:/Users/Itshony/Desktop/캡스톤/Documents/Capstone/Seoul_location/종로구 실거래(13~18).xlsx")

# %%
A = ['강남구','강동구','강북구','강서구','관악구','광진구','구로구','금천구','노원구','도봉구','동대문구','동작구','마포구',
     '서대문구','서초구','성동구','성북구','송파구','양천구','영등포구','용산구','은평구','종로구','중구','중랑구']

# %% [markdown]
# # 데이터 통합

# %%
A = ['강남구','강동구','강북구','강서구','관악구','광진구','구로구','금천구','노원구','도봉구','동대문구','동작구','마포구',
     '서대문구','서초구','성동구','성북구','송파구','양천구','영등포구','용산구','은평구','종로구','중구','중랑구']

Temp1 = pd.DataFrame(columns= list(data.columns))

for i in A:
    Temp2 = pd.read_excel('C:/Users/Itshony/Desktop/캡스톤/Documents/Capstone/Seoul_location/%s 실거래(13~18).xlsx'%i)
    Temp2['구'] = i
    Temp1 = pd.concat([Temp1, Temp2], axis = 0)
    print(i, len(Temp2), len(Temp1))

Temp1 = Temp1.reset_index(drop=True)
data = Temp1.copy()
# Out:
# 강남구 35089 35089
# 강동구 29823 64912
# 강북구 11162 76074
# 강서구 35174 111248
# 관악구 18305 129553
# 광진구 11426 140979
# 구로구 29243 170222
# 금천구 9590 179812
# 노원구 56698 236510
# 도봉구 24921 261431
# 동대문구 19928 281359
# 동작구 21966 303325
# 마포구 20985 324310
# 서대문구 16179 340489
# 서초구 26566 367055
# 성동구 21181 388236
# 성북구 29946 418182
# 송파구 38147 456329
# 양천구 27283 483612
# 영등포구 24162 507774
# 용산구 11210 518984
# 은평구 18681 537665
# 종로구 4411 542076
# 중구 6991 549067
# 중랑구 17593 566660

# %%
data.drop(['Unnamed: 0'], axis='columns', inplace=True)

# %%
data.drop(['Unnamed: 0.1'], axis='columns', inplace=True)

# %%
data = data.drop(['국내총생산', '경제성장률','소비자물가', '집세', '환율'],axis=1)

# %%
data1 = data.drop(['도로명건물본번호코드', '도로명건물부번호코드', '도로명시군구코드',
       '도로명일련번호코드', '도로명코드','법정동본번코드', '법정동부번코드', '법정동시군구코드',
       '법정동읍면동코드', '법정동지번코드','일련번호', '지번', '지역코드','location','address'],axis=1)

# %%
data1['거래금액']=data['거래금액'].str.replace(',','').astype('int64')
data1['건축년도']=data1['건축년도'].astype('int64')
data['년']=data['년'].astype('int64')
data1['월'] = data['월'].astype('int64')
data1['일']=data['일'].astype('int64')
data1['전용면적']=data['전용면적'].astype('float64')
data1['층']=data1['층'].astype('int64')

# %%
년별_매매가_평균값 = data1.groupby('년').거래금액.mean().reset_index()

# %%
plt.plot?

# %%
plt.figure(figsize=(15,5))
plt.plot(년별_매매가_평균값['년'],년별_매매가_평균값['거래금액'],linewidth=5)
plt.title('거래년별 서울시 아파트 평균 매매가',fontsize=20)
plt.xlabel('거래년도',fontsize=13)
plt.ylabel('평균 매매가',fontsize=13)
plt.grid(True)

# %%
data1.head(3)
# Out:
#          거래금액  건축년도     년     도로명   법정동       아파트  월  일   전용면적   층    구
# 0      22,116  2012  2013  역삼로25길   역삼동  요진와이시티미니  1  2  16.41   5  강남구
# 1      29,000  2002  2013  도곡로57길   역삼동       트레벨  1  5  33.48   4  강남구
# 2      90,000  2009  2013  도곡로43길   역삼동   래미안그레이튼  1  6  84.97  13  강남구

# %%
data1['거래금액']=data['거래금액'].str.replace(',','').astype('int64')
data1['건축년도']=data1['건축년도'].astype('int64')
data['년']=data['년'].astype('int64')
data1['월'] = data['월'].astype('int64')
data1['일']=data['일'].astype('int64')
data1['전용면적']=data['전용면적'].astype('float64')
data1['층']=data1['층'].astype('int64')

# %%
# 구 분리 
강남구= data1[data1['구'] == '강남구']
강동구= data1[data1['구'] == '강동구']
강북구= data1[data1['구'] == '강북구']
강서구= data1[data1['구'] == '강서구']
관악구= data1[data1['구'] == '관악구']
광진구= data1[data1['구'] == '광진구']
구로구= data1[data1['구'] == '구로구']
금천구= data1[data1['구'] == '금천구']
노원구= data1[data1['구'] == '노원구']
도봉구= data1[data1['구'] == '도봉구']
동대문구= data1[data1['구'] == '동대문구']
동작구= data1[data1['구'] == '동작구']
마포구= data1[data1['구'] == '마포구']
서대문구= data1[data1['구'] == '서대문구']
서초구= data1[data1['구'] == '서초구']
성동구= data1[data1['구'] == '성동구']
성북구= data1[data1['구'] == '성북구']
송파구= data1[data1['구'] == '송파구']
양천구= data1[data1['구'] == '양천구']
영등포구= data1[data1['구'] == '영등포구']
용산구= data1[data1['구'] == '용산구']
은평구= data1[data1['구'] == '은평구']
종로구= data1[data1['구'] == '종로구']
중구= data1[data1['구'] == '중구']
중랑구= data1[data1['구'] == '중랑구']
종로구 = data1[data1['구'] == '종로구']

# %% [markdown]
# # 파생변수 생성

# %% [markdown]
# ## 1. 년별 동일지역 동일면적 매매가 평균 (YR_AVEG)

# %%
강남구['전용면적_cut']=pd.cut(강남구.전용면적,bins=[0,40,51.4,62.8,79.35,95.9,110,135,424.32],labels=[1,2,3,4,5,6,7,8])
# Out:
# C:\Users\Itshony\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
강남구['아파트_전용면적']=''
# Out:
# C:\Users\Itshony\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
강남구.head(3)
# Out:
#     거래금액  건축년도     년     도로명   법정동       아파트  월  일   전용면적   층        lat  \
# 0  22116  2012  2013  역삼로25길   역삼동  요진와이시티미니  1  2  16.41   5  37.497682
# 1  29000  2002  2013  도곡로57길   역삼동       트레벨  1  5  33.48   4  37.496089
# 2  90000  2009  2013  도곡로43길   역삼동   래미안그레이튼  1  6  84.97  13  37.496427
#
#           lng    구 전용면적_cut 아파트_전용면적
# 0  127.039468  강남구        1
# 1  127.050378  강남구        1
# 2  127.048299  강남구        5

# %%
강남구['아파트_전용면적_거래금액_평균']=''
강남구.rename(columns={'아파트_전용면적_거래금액_평균':'YR_AVEG','아파트_전용면적_건수':'YR_COUNT'},inplace=True)
강남구.head(3)
# Out:
# C:\Users\Itshony\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Itshony\Anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#     거래금액  건축년도     년     도로명   법정동       아파트  월  일   전용면적   층        lat  \
# 0  22116  2012  2013  역삼로25길   역삼동  요진와이시티미니  1  2  16.41   5  37.497682
# 1  29000  2002  2013  도곡로57길   역삼동       트레벨  1  5  33.48   4  37.496089
# ...

# %%
강남구.to_excel('강남구_2.xlsx')

# %%
강남구['YR_AVEG']=''
# Out:
# C:\Users\Itshony\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
list1=강남구.groupby(['도로명','년','전용면적_cut']).거래금액.mean().reset_index()

# %%
list1=list1.dropna(axis=0)

# %%
list1.head(3)
# Out:
#     도로명     년 전용면적_cut          거래금액
# 0  강남대로  2013        1  24125.000000
# 1  강남대로  2013        2  38500.000000
# 3  강남대로  2013        4  44814.285714

# %%
list1.rename(columns = {'거래금액':'YR_AVEG'},inplace = True)

# %%
list1.dtypes
# Out:
# 도로명           object
# 년              int64
# 전용면적_cut    category
# YR_AVEG      float64
# dtype: object

# %%
list1.to_excel('년별 동일지역 동일면적 매매가 평균.xlsx')

# %%
강남구['YR_COUNT']=''

# %%
강남구.head(3)
# Out:
#     거래금액  건축년도     년     도로명   법정동       아파트  월  일   전용면적   층    구 전용면적_cut  \
# 0  22116  2012  2013  역삼로25길   역삼동  요진와이시티미니  1  2  16.41   5  강남구        1
# 1  29000  2002  2013  도곡로57길   역삼동       트레벨  1  5  33.48   4  강남구        1
# 2  90000  2009  2013  도곡로43길   역삼동   래미안그레이튼  1  6  84.97  13  강남구        5
#
#   YR_AVEG YR_COUNT
# 0
# 1
# 2

# %%
강남구.to_excel('강남구 변수추가.xlsx')

# %%
if list1

# %% [markdown]
# ## 2. 년별 도로명별 동일면적별 매매건수 (YR_COUNT)

# %%
list2=강남구.groupby(['년','도로명','전용면적_cut']).거래금액.count().reset_index()

# %%
# 강남구[(강남구['도로명']=='강남대로') & (강남구['년']==2013)].sort_values(by=['전용면적_cut'],axis=0).head(23)

# %%
list2.rename(columns = {'거래금액' : 'YR_COUNT'}, inplace = True)

# %%
list2.head(3)
# Out:
#       년   도로명 전용면적_cut  YR_COUNT
# 0  2013  강남대로        1        10
# 1  2013  강남대로        2         2
# 2  2013  강남대로        3         0

# %% [markdown]
# ## case 1. 파생변수 매칭 (년별 아파트별 동일면적별 매매건수, 개수)

# %%
for i in range(len(강남구)):
    강남구.at[i,'아파트_전용면적']=(str(강남구.at[i,'년'])+강남구.at[i,'아파트']+str(강남구.at[i,'전용면적_cut']))

# %%
B=강남구.아파트_전용면적.unique()
B
# Out:
# array(['2013요진와이시티미니1', '2013트레벨1', '2013래미안그레이튼5', ..., '2018채널리저브8',
#        '2018논현동월드메르디앙5', '2018파크힐3'], dtype=object)

# %%
강남구.아파트_전용면적.head(10)
# Out:
# 0    2013요진와이시티미니1
# 1         2013트레벨1
# 2     2013래미안그레이튼5
# 3       2013역삼래미안3
# 4      2013e-편한세상3
# 5     2013강남서해더블루4
# 6       2013역삼래미안3
# 7     2013강남서해더블루4
# 8     2013강남서해더블루4
# 9     2013강남서해더블루4
# Name: 아파트_전용면적, dtype: object

# %%
for i in B:
    X = np.where(강남구.아파트_전용면적 == i)
    print(X[0])
    print(len(X[0]))
    print(round(강남구.거래금액[X[0]].mean()))
# Out:
# [   0  318  319  332  333  718  727 1132 1133 1134 1145 1170 1171 1172
#  1175 1180 1605 1991 2025 2478 2787 2788 2789 3113 3114 3121 3518 3524
#  3525 3526 3527 3531 3533 3929]
# 34
# 20359
# [   1   21 3922]
# 3
# 30450
# [   2  312  707 2336 3916]
# 5
# 95500
# [   3    6   13   18  322  323  330  706  739 1147 1159 1166 1167 1168
#  1169 1173 1607 1614 1627 1990 1993 1999 2011 2019 2323 2482 2485 2497
#  2757 2760 2768 2769 2775 3110 3115 3116 3118 3542 3553 3912 3917 3938
#  3948 3951]
# 44
# 64402
# [   4   23  328  329  699  703  705  726  740 1130 1138 1156 1163 1183
#  1186 1194 2004 2338 2480 2483 2488 2498 2751 2764 2783 2791 2793 2799
#  3108 3111 3127 3927 3932 3949 3967]
# 35
# 67877
# [   5    7    8    9   10   19  321 1177 1636]
# 9
# 55447
# [  11   20  720 1146 1623 2006 2007 2018 2335 3123 3520 3933]
# 12
# 33433
# [  12 1161]
# 2
# 53500
# [  14   27 1128 1599 2016 2766 2767 2770 2795 2796 3126 3142 3546 3552
#  3964]
# 15
# 88013
# [  15   30 2481 3138]
# 4
# ...

# %%
for i in B:
    X = np.where(강남구.아파트 == i)
    
    for j in X[0]:
        강남구.at[j,'YR_COUNT'] = len(X[0])
        강남구.at[j,'YR_AVEG'] = round(강남구.거래금액[X[0]].mean(),0)

# %%
강남구.YR_AVEG=강남구.YR_AVEG.astype('int64')
강남구.YR_COUNT=강남구.YR_COUNT.astype('int64')

# %%
강남구['거래금액'].corr(강남구['YR_AVEG'])
# Out:
# 0.9724810124475792

# %%
강남구['거래금액'].corr(강남구['YR_COUNT'])
# Out:
# -0.06978198147501967

# %%
강남구['거래금액'].corr(강남구['전용면적_cut'])
# Out:
# 0.6864770863328542

# %% [markdown]
# ## case 2. 파생변수 매칭 (년별  도로명별 동일면적별 매매건수, 개수)

# %%
강남구['도로명_전용면적']=''
# Out:
# C:\Users\Itshony\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in range(len(강남구)):
    강남구.at[i,'도로명_전용면적']=(str(강남구.at[i,'년'])+강남구.at[i,'도로명']+str(강남구.at[i,'전용면적_cut']))

# %%
B1=강남구.도로명_전용면적.unique()
B1
# Out:
# array(['2013역삼로25길1', '2013도곡로57길1', '2013도곡로43길5', ..., '2018논현로2길4',
#        '2018학동로38길5', '2018도곡로14길3'], dtype=object)

# %%
for i in B1:
    X = np.where(강남구.도로명_전용면적 == i)
    print(X[0])
    print(len(X[0]))
    print(round(강남구.거래금액[X[0]].mean()))
# Out:
# [   0  318  319  332  333  718  727 1132 1133 1134 1145 1170 1171 1172
#  1175 1180 1605 1991 2025 2322 2478 2787 2788 2789 3113 3114 3121 3518
#  3524 3525 3526 3527 3531 3533 3929]
# 35
# 20349
# [   1   21 3922]
# 3
# 30450
# [   2  312  707 2336 2499 3916 3936]
# 7
# 94343
# [   3    4    6   13   18   23  322  323  328  329  330  699  703  705
#   706  726  739  740 1130 1138 1147 1156 1159 1163 1166 1167 1168 1169
#  1173 1183 1186 1194 1607 1614 1627 1990 1993 1999 2004 2011 2019 2323
#  2338 2480 2482 2483 2485 2488 2497 2498 2751 2757 2760 2764 2768 2769
#  2775 2783 2791 2793 2799 3108 3110 3111 3115 3116 3118 3127 3542 3553
#  3912 3917 3927 3932 3938 3948 3949 3951 3967]
# 79
# 65942
# [   5    7    8    9   10   19  321 1177 1636]
# 9
# 55447
# [  11   20  720 1146 1623 2006 2007 2018 2335 3123 3520 3933]
# 12
# 33433
# [  12 1161]
# 2
# 53500
# [  14   27  270  394  652  677 1079 1113 1128 1197 1558 1570 1576 1599
# ...

# %%
강남구['ROAD_COUNT']=''
강남구['ROAD_AVEG']=''
# Out:
# C:\Users\Itshony\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Itshony\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for i in B1:
    X = np.where(강남구.도로명_전용면적 == i)
    
    for j in X[0]:
        강남구.at[j,'ROAD_COUNT'] = len(X[0])
        강남구.at[j,'ROAD_AVEG'] = round(강남구.거래금액[X[0]].mean(),0)

# %%
강남구.ROAD_COUNT=강남구.ROAD_COUNT.astype('int64')
강남구.ROAD_AVEG=강남구.ROAD_AVEG.astype('int64')
# Out:
# C:\Users\Itshony\Anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
강남구['ROAD_COUNT'].corr(강남구['거래금액'])
# Out:
# 0.10482430871173373

# %%
강남구['ROAD_AVEG'].corr(강남구['거래금액'])
# Out:
# 0.946400381002672

# %% [markdown]
# ## case 3. 파생변수 매칭 (년별  법정동별 동일면적별 매매건수, 개수)

# %%
강남구['법정동_전용면적']=''
# Out:
# C:\Users\Itshony\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in range(len(강남구)):
    강남구.at[i,'법정동_전용면적']=(str(강남구.at[i,'년'])+강남구.at[i,'법정동']+str(강남구.at[i,'전용면적_cut']))

# %%
B2=강남구.법정동_전용면적.unique()
B2
# Out:
# array(['2013 역삼동1', '2013 역삼동5', '2013 역삼동3', '2013 역삼동4', '2013 역삼동7',
#        '2013 개포동1', '2013 개포동2', '2013 개포동4', '2013 개포동3', '2013 개포동5',
#        '2013 개포동6', '2013 개포동7', '2013 청담동8', '2013 청담동6', '2013 청담동5',
#        '2013 청담동3', '2013 삼성동1', '2013 삼성동6', '2013 삼성동8', '2013 삼성동3',
#        '2013 삼성동5', '2013 삼성동4', '2013 삼성동7', '2013 삼성동2', '2013 대치동7',
#        '2013 대치동4', '2013 대치동5', '2013 대치동8', '2013 대치동1', '2013 대치동6',
#        '2013 신사동3', '2013 신사동7', '2013 신사동5', '2013 신사동6', '2013 신사동4',
#        '2013 논현동5', '2013 논현동1', '2013 논현동8', '2013 압구정동4', '2013 압구정동5',
#        '2013 압구정동8', '2013 압구정동6', '2013 압구정동7', '2013 압구정동3',
#        '2013 세곡동5', '2013 일원동3', '2013 일원동1', '2013 수서동5', '2013 수서동2',
#        '2013 수서동1', '2013 수서동6', '2013 수서동3', '2013 도곡동8', '2013 도곡동7',
#        '2013 도곡동5', '2013 도곡동3', '2013 도곡동6', '2013 도곡동1', '2013 역삼동2',
#        '2013 역삼동8', '2013 개포동8', '2013 청담동1', '2013 청담동4', '2013 청담동7',
# ...

# %%
for i in B2:
    X = np.where(강남구.법정동_전용면적 == i)
    print(X[0])
    print(len(X[0]))
    print(round(강남구.거래금액[X[0]].mean()))
# Out:
# [   0    1   11   17   20   21  318  319  332  333  334  701  710  712
#   718  720  722  724  727  731 1132 1133 1134 1140 1145 1146 1155 1170
#  1171 1172 1175 1180 1182 1185 1196 1600 1601 1602 1603 1604 1605 1612
#  1622 1623 1628 1630 1635 1991 1992 2001 2006 2007 2010 2017 2018 2025
#  2322 2324 2325 2326 2327 2328 2329 2330 2334 2335 2478 2484 2756 2763
#  2779 2782 2787 2788 2789 2790 3113 3114 3120 3121 3123 3128 3143 3507
#  3511 3518 3520 3524 3525 3526 3527 3531 3533 3914 3922 3928 3929 3933
#  3963 3968]
# 100
# 23287
# [   2   12   14   15   16   24   26   27   28   30  312  313  314  316
#   317  326  707  715  717  725  735 1128 1136 1141 1142 1144 1153 1154
#  1157 1158 1161 1164 1179 1184 1187 1188 1190 1193 1197 1599 1609 1611
#  1624 1626 1637 1994 1995 2000 2002 2008 2013 2016 2020 2026 2321 2332
#  2336 2477 2479 2481 2493 2496 2499 2501 2504 2506 2753 2754 2759 2765
#  2766 2767 2770 2772 2773 2776 2778 2781 2785 2786 2795 2796 2797 3101
# ...

# %%
강남구['DONG_COUNT']=''
강남구['DONG_AVEG']=''
# Out:
# C:\Users\Itshony\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Itshony\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for i in B2:
    X = np.where(강남구.법정동_전용면적 == i)
    
    for j in X[0]:
        강남구.at[j,'DONG_COUNT'] = len(X[0])
        강남구.at[j,'DONG_AVEG'] = round(강남구.거래금액[X[0]].mean(),0)

# %%
강남구.DONG_COUNT=강남구.DONG_COUNT.astype('int64')
강남구.DONG_AVEG=강남구.DONG_AVEG.astype('int64')
# Out:
# C:\Users\Itshony\Anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
강남구['DONG_AVEG'].corr(강남구['거래금액'])
# Out:
# 0.8678659814014287

# %%
강남구['DONG_COUNT'].corr(강남구['거래금액'])
# Out:
# -0.044140656335514644

# %% [markdown]
# ## 3. 거래된 년의 아파트 연식

# %%
강남구['연식']=''

# %%
강남구['연식']=강남구['년']-강남구['건축년도']

# %%
강남구['연식']
# Out:
# 0         1
# 1        11
# 2         4
# 3         8
# 4         8
#          ..
# 35084    13
# 35085    12
# 35086    11
# 35087    22
# 35088    40
# Name: 연식, Length: 35089, dtype: object

# %%
강남구['거래금액'].corr(강남구['연식'].astype('int64'))
#강남구['거래금액'].corr(강남구['전용면적_cut'])
# Out:
# 0.10447053711092331

# %%
sns.heatmap(강남구, annot=True, fmt='d')

plt.title('Annoteat cell with numeric value', fontsize=20)

plt.show()
